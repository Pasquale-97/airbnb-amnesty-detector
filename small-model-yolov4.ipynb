# %% [markdown]
# # YoloV4 - Small Model
#
# A small model for testing of the YoloV4 model on the Billiard Data downloaded from OpenImages.

# %%
# TO DO:
# Download Yolov4 to create a small model
# For future use: use the convert python file to convert the file in the correct format
