# %% [markdown]
# # Airbnb Data Management
# This is a notebook used to sort all the data for the Airbnb Amnesty Project.
# To see the full project *insert link here*.

# %%
# !ls
# Out:
# airbnb-data-v2		images	 modules    remove_space.py
# classes.txt		LICENSE  OID	    requirements.txt
# convert_annotations.py	main.py  README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/airbnb/
# Out:
# /content/drive/MyDrive/airbnb

# %% [markdown]
# ## OIDv6
# Downloading and using the OIDv6 library to download images from Open Images. In this case the category kitchen and dining room table.

# %%
# !pip install oidv6
# Out:
# ...
#      |████████████████████████████████| 57.4MB 74kB/s
# ...
#      |████████████████████████████████| 133kB 48.6MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
#   Found existing installation: progressbar2 3.38.0
#     Uninstalling progressbar2-3.38.0:
#       Successfully uninstalled progressbar2-3.38.0
#   Found existing installation: urllib3 1.26.5
#     Uninstalling urllib3-1.26.5:
#       Successfully uninstalled urllib3-1.26.5
# ...

# %%
pip install --upgrade oidv6
# Out:
# Requirement already up-to-date: oidv6 in /usr/local/lib/python3.7/dist-packages (1.0.5)
# ...

# %%
# !oidv6 downloader en --dataset /content/drive/MyDrive/airbnb/Data --type_data all --classes "Kitchen & dining room table"
# Out:
# --------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# --------------------------------------------------------------------------------
# [2021-06-02 15:59:13] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# --------------------------------------------------------------------------------
# [2021-06-02 15:59:13] Checking command line arguments for validity ...
# [2021-06-02 15:59:13] Creating Directories for Metadata ...
# --------------------------------------------------------------------------------
# [2021-06-02 15:59:13] Downloading "kitchen & dining room table" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Do you want to download the missing file? [Y/n] Y
#         Automatic download ... 24 out of 24 (100%)
#     File "oidv6-train-annotations-bbox.csv" not found ...
# ...

# %% [markdown]
# ## OIDv4
# Used to download all the categories for the Airbnb Amnesty Detector. This includes the remaining 29 categories.

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 18.46 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.6MB 6.7MB/s
# ...
#      |████████████████████████████████| 81kB 8.0MB/s
# ...
#      |████████████████████████████████| 552kB 34.4MB/s
# ...
#      |████████████████████████████████| 7.6MB 40.2MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.20.84 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !python3 /content/drive/MyDrive/airbnb/OIDv4_ToolKit/main.py downloader --classes Toilet Swimming_pool Sink Fountain Oven Ceiling_fan Television Microwave_oven Gas_stove Refrigerator Washing_machine Bathtub Stairs Fireplace Pillow Mirror Shower Couch Countertop Coffeemaker Dishwasher Sofa_bed Tree_house Towel Porch Wine_rack Jacuzzi --type_csv all
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Toilet.
#
# Toilet
#     [INFO] | Downloading all images.
#     [INFO] | [INFO] Found 862 online images for train.
#     [INFO] | Download of 862 images in train.
# 100% 862/862 [08:06<00:00,  1.77it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toilet of train.
# ...

# %%
# !python3 /content/drive/MyDrive/airbnb/OIDv4_ToolKit/main.py downloader --classes "Kitchen & dining room table" --type_csv all
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Kitchen & dining room table.
#
# Kitchen & dining room table
#     [INFO] | Downloading all images.
#     [INFO] | [INFO] Found 1966 online images for train.
#     [INFO] | Download of 1917 images in train.
# 100% 1917/1917 [20:22<00:00,  1.57it/s]
#     [INFO] | Done!
# ...

# %% [markdown]
# ## Using Python for Data Formatting
# Writing Python scripts to convert the images from Open Image format into the YOLOv5 format.

# %% [markdown]
# A Python Script to remove all the spaces in the labels.

# %%
# !python3 remove_space.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Billiard table
# 100% 666/666 [00:04<00:00, 136.28it/s]
# Converting annotations for class:  Ceiling fan
# 100% 431/431 [01:13<00:00,  5.90it/s]
# Converting annotations for class:  Microwave oven
# 100% 432/432 [01:12<00:00,  5.96it/s]
# Converting annotations for class:  Sofa bed
# 100% 1132/1132 [04:03<00:00,  4.65it/s]
# Converting annotations for class:  Swimming pool
# 100% 3618/3618 [10:26<00:00,  5.77it/s]
# Converting annotations for class:  Tree house
# 100% 107/107 [00:18<00:00,  5.92it/s]
# Converting annotations for class:  Washing machine
# 100% 326/326 [01:04<00:00,  5.03it/s]
# Converting annotations for class:  Wine rack
# 100% 140/140 [00:23<00:00,  5.86it/s]
# Converting annotations for class:  Gas stove
# 100% 473/473 [01:23<00:00,  5.67it/s]
# Converting annotations for class:  Kitchen & dining room table
# 100% 1966/1966 [00:14<00:00, 132.90it/s]
# Currently in subdirectory: validation
# ...

# %% [markdown]
# Python script to convert the file into the correct YOLOv5 format.

# %%
# !python3 convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Sink
# 100% 1442/1442 [00:48<00:00, 29.55it/s]
# Converting annotations for class:  Fountain
# 100% 3089/3089 [01:45<00:00, 29.20it/s]
# Converting annotations for class:  Oven
# 100% 509/509 [00:17<00:00, 29.84it/s]
# Converting annotations for class:  Television
# 100% 2789/2789 [01:35<00:00, 29.12it/s]
# Converting annotations for class:  Refrigerator
# 100% 549/549 [00:16<00:00, 33.56it/s]
# Converting annotations for class:  Bathtub
# 100% 533/533 [00:15<00:00, 34.31it/s]
# Converting annotations for class:  Stairs
# 100% 4533/4533 [02:41<00:00, 28.02it/s]
# Converting annotations for class:  Fireplace
# 100% 685/685 [00:20<00:00, 33.29it/s]
# Converting annotations for class:  Pillow
# 100% 1249/1249 [01:22<00:00, 15.11it/s]
# Converting annotations for class:  Mirror
# 100% 1146/1146 [00:40<00:00, 28.57it/s]
# Converting annotations for class:  Shower
# 100% 206/206 [00:06<00:00, 32.45it/s]
# ...

# %% [markdown]
# Removing the old labels folder

# %%
# # remove old labels file from train
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Bathtub"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Billiard table"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Ceiling fan"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Coffeemaker"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Couch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Countertop"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Dishwasher"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Fireplace"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Fountain"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Gas stove"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Jacuzzi"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Microwave oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Mirror"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Pillow"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Porch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Refrigerator"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Shower"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Sink"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Sofa bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Stairs"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Swimming pool"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Television"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Toilet"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Towel"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Tree house"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Washing machine"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"Wine rack"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/train/"kitchen_&_dining_room_table"/Label

# %%
# # remove old labels file from validation
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Bathtub"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Billiard table"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Ceiling fan"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Coffeemaker"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Couch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Countertop"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Dishwasher"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Fireplace"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Fountain"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Gas stove"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Jacuzzi"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Microwave oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Mirror"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Pillow"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Porch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Refrigerator"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Shower"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Sink"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Sofa bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Stairs"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Swimming pool"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Television"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Toilet"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Towel"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Tree house"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Washing machine"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"Wine rack"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/validation/"kitchen_&_dining_room_table"/Label

# %%
# # remove old labels file from test
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Bathtub"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Billiard table"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Ceiling fan"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Coffeemaker"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Couch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Countertop"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Dishwasher"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Fireplace"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Fountain"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Gas stove"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Jacuzzi"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Microwave oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Mirror"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Oven"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Pillow"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Porch"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Refrigerator"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Shower"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Sink"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Sofa bed"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Stairs"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Swimming pool"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Television"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Toilet"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Towel"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Tree house"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Washing machine"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"Wine rack"/Label
# !rm -r /content/drive/MyDrive/airbnb/OIDv4_ToolKit/Data-v2/Dataset/test/"kitchen_&_dining_room_table"/Label

# %% [markdown]
# ## Moving Files
# Move files into one for images and labels per category

# %%
# %cd Bed/
# Out:
# /content/drive/MyDrive/airbnb-crap/Airbnb-Data/Dataset/train/Bed

# %%
from PIL import Image

im = Image.open('00041cc3701f7805.jpg')
im.size
print(im.size)
# Out:
# (1024, 677)

# %%
# !python3 move_files.py
